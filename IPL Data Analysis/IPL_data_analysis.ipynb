# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('data/deliveries.csv')
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# %matplotlib inline
data.head(30).plot(x='ball', y='total_runs')

# %%
data[data['over']==1].head()['batsman']
# Out:
# 0    DA Warner
# 1    DA Warner
# 2    DA Warner
# 3    DA Warner
# 4    DA Warner
# Name: batsman, dtype: object

# %%
over = data[(data['match_id'] == 1)]
run = data[(data['match_id']==1) & (data['over']==1)]['total_runs'].sum()
run
# Out:
# 18

# %%
over = data[(data['match_id'] == 1)]
over
# Out:
# match_id                                                       248
# inning                                                         371
# batting_team     Sunrisers HyderabadSunrisers HyderabadSunriser...
# bowling_team     Royal Challengers BangaloreRoyal Challengers B...
# over                                                          2571
# ball                                                           900
# batsman          DA WarnerDA WarnerDA WarnerDA WarnerDA WarnerS...
# non_striker      S DhawanS DhawanS DhawanS DhawanS DhawanDA War...
# bowler           TS MillsTS MillsTS MillsTS MillsTS MillsTS Mil...
# is_super_over                                                    0
# wide_runs                                                        9
# bye_runs                                                         0
# legbye_runs                                                      2
# noball_runs                                                      2
# ...

# %%
data.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
match = pd.read_csv('data/matches.csv')

# %%
match['player_of_match'].value_counts().head(15)
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# DA Warner         17
# RG Sharma         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# MEK Hussey        12
# AM Rahane         12
# V Sehwag          11
# DR Smith          11
# A Mishra          11
# Name: player_of_match, dtype: int64

# %%
match['player_of_match'].value_counts().head(25).plot(kind='pie', figsize = (8,8))

# %%
match['winner'].value_counts().plot(kind='bar', figsize=(15,4))

# %%
match['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# DA Warner         17
# RG Sharma         17
#                   ..
# J Archer           1
# Ishan Kishan       1
# MF Maharoof        1
# TA Boult           1
# HH Gibbs           1
# Name: player_of_match, Length: 226, dtype: int64

# %%
print(match.columns)
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
match['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Kings XI Punjab                81
# Royal Challengers Bangalore    81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
match['venue'].value_counts().head()
# Out:
# Eden Gardens                                 77
# M Chinnaswamy Stadium                        73
# Wankhede Stadium                             73
# Feroz Shah Kotla                             67
# Rajiv Gandhi International Stadium, Uppal    56
# Name: venue, dtype: int64
