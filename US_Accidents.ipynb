# %% [markdown]
# ### *US* Accidents Analysis
#
# *   Kaggle dataset on US accidents
# *   Analyzing data to understand area, weather conditions and timings of accidents
# *   Finding how well spread data is accross country and missing states and cities

# %% [markdown]
# US accidents Exploratory Data Analysis
#
#
# 1. City
# 2. Start Time
# 3. Lattitude and Longitutde
# 4. Temprature

# %%
pip install opendatasets --upgrade

# %%
import opendatasets as od
url = 'https://www.kaggle.com/sobhanmoosavi/us-accidents'
od.download(url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: siddharthabadal
# Your Kaggle Key: ··········
#   4%|▎         | 11.0M/299M [00:00<00:02, 115MB/s]
# ...
# 100%|██████████| 299M/299M [00:01<00:00, 227MB/s]

# %%
data_file = './us-accidents/US_Accidents_Dec20.csv'

# %% [markdown]
# ##Data Preparation and cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv(data_file)

# %%
df
# Out:
#                 ID    Source  ...  Nautical_Twilight  Astronomical_Twilight
# 0              A-1  MapQuest  ...              Night                  Night
# 1              A-2  MapQuest  ...              Night                    Day
# 2              A-3  MapQuest  ...                Day                    Day
# 3              A-4  MapQuest  ...                Day                    Day
# 4              A-5  MapQuest  ...                Day                    Day
# ...            ...       ...  ...                ...                    ...
# 4232536  A-4239402      Bing  ...                Day                    Day
# 4232537  A-4239403      Bing  ...                Day                    Day
# 4232538  A-4239404      Bing  ...                Day                    Day
# 4232539  A-4239405      Bing  ...                Day                    Day
# 4232540  A-4239406      Bing  ...                Day                    Day
#
# [4232541 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4232541 entries, 0 to 4232540
# Data columns (total 49 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               int64
#  4   Start_Time             object
#  5   End_Time               object
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance(mi)           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
# ...

# %%
df.describe()
# Out:
#                 TMC      Severity  ...  Wind_Speed(mph)  Precipitation(in)
# count  2.716477e+06  4.232541e+06  ...     3.753215e+06       2.166952e+06
# mean   2.083517e+02  2.305035e+00  ...     7.903433e+00       1.244719e-02
# std    2.124413e+01  5.332261e-01  ...     5.330998e+00       1.637154e-01
# min    2.000000e+02  1.000000e+00  ...     0.000000e+00       0.000000e+00
# 25%    2.010000e+02  2.000000e+00  ...     4.600000e+00       0.000000e+00
# 50%    2.010000e+02  2.000000e+00  ...     7.000000e+00       0.000000e+00
# 75%    2.010000e+02  3.000000e+00  ...     1.040000e+01       0.000000e+00
# max    4.060000e+02  4.000000e+00  ...     9.840000e+02       2.500000e+01
#
# [8 rows x 15 columns]

# %%
df['Number'].describe()
# Out:
# count    1.544592e+06
# mean     6.141507e+03
# std      1.492268e+04
# min      0.000000e+00
# 25%      8.980000e+02
# 50%      2.890000e+03
# 75%      7.330000e+03
# max      9.999997e+06
# Name: Number, dtype: float64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 15

# %% [markdown]
# Percantage of missing values

# %%
df.isna()
# Out:
#             ID  Source  ...  Nautical_Twilight  Astronomical_Twilight
# 0        False   False  ...              False                  False
# 1        False   False  ...              False                  False
# 2        False   False  ...              False                  False
# 3        False   False  ...              False                  False
# 4        False   False  ...              False                  False
# ...        ...     ...  ...                ...                    ...
# 4232536  False   False  ...              False                  False
# 4232537  False   False  ...              False                  False
# 4232538  False   False  ...              False                  False
# 4232539  False   False  ...              False                  False
# 4232540  False   False  ...              False                  False
#
# [4232541 rows x 49 columns]

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# End_Lat                  6.418076e-01
# End_Lng                  6.418076e-01
# Number                   6.350674e-01
# Precipitation(in)        4.880258e-01
# Wind_Chill(F)            4.479581e-01
# TMC                      3.581924e-01
# Wind_Speed(mph)          1.132478e-01
# Visibility(mi)           2.331176e-02
# Weather_Condition        2.324443e-02
# Humidity(%)              2.255548e-02
# Temperature(F)           2.124020e-02
# Wind_Direction           1.975433e-02
# Pressure(in)             1.804684e-02
# Weather_Timestamp        1.480057e-02
# Airport_Code             2.120003e-03
# Timezone                 1.090362e-03
# Zipcode                  3.052540e-04
# Nautical_Twilight        3.331332e-05
# Astronomical_Twilight    3.331332e-05
# Civil_Twilight           3.331332e-05
# Sunrise_Sunset           3.331332e-05
# City                     3.236826e-05
# Description              4.725294e-07
# Amenity                  0.000000e+00
# Street                   0.000000e+00
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages != 0]
# Out:
# End_Lat                  6.418076e-01
# End_Lng                  6.418076e-01
# Number                   6.350674e-01
# Precipitation(in)        4.880258e-01
# Wind_Chill(F)            4.479581e-01
# TMC                      3.581924e-01
# Wind_Speed(mph)          1.132478e-01
# Visibility(mi)           2.331176e-02
# Weather_Condition        2.324443e-02
# Humidity(%)              2.255548e-02
# Temperature(F)           2.124020e-02
# Wind_Direction           1.975433e-02
# Pressure(in)             1.804684e-02
# Weather_Timestamp        1.480057e-02
# Airport_Code             2.120003e-03
# Timezone                 1.090362e-03
# Zipcode                  3.052540e-04
# Nautical_Twilight        3.331332e-05
# Astronomical_Twilight    3.331332e-05
# Civil_Twilight           3.331332e-05
# Sunrise_Sunset           3.331332e-05
# City                     3.236826e-05
# Description              4.725294e-07
# dtype: float64

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')

# %% [markdown]
# ## Columns to analyze
#
# ---
# city |  Start time | Start Lng | Temprature | weather Condition

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 4232536       Riverside
# 4232537       San Diego
# 4232538          Orange
# 4232539     Culver City
# 4232540        Highland
# Name: City, Length: 4232541, dtype: object

# %%
len(df.City.unique())
# Out:
# 12251

# %%
cities_byaccident = df.City.value_counts()
cities_byaccident
# Out:
# Houston               114905
# Los Angeles            92701
# Charlotte              88887
# Dallas                 77303
# Austin                 70538
#                        ...
# Mooers Forks               1
# Wewoka                     1
# Wrightsville Beach         1
# Falkner                    1
# Kimballton                 1
# Name: City, Length: 12250, dtype: int64

# %%
cities_byaccident[:10]
# Out:
# Houston        114905
# Los Angeles     92701
# Charlotte       88887
# Dallas          77303
# Austin          70538
# Miami           63162
# Raleigh         52876
# Atlanta         46328
# Baton Rouge     42814
# Nashville       41850
# Name: City, dtype: int64

# %%
'New York City' in df.City
# Out:
# False

# %%
cities_byaccident[:25].plot(kind='barh')

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.distplot(cities_byaccident)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
high_accidents_cities = cities_byaccident[cities_byaccident >= 1000]
low_accidents_cities = cities_byaccident[cities_byaccident < 1000]

# %%
len(high_accidents_cities)
# Out:
# 704

# %%
len(low_accidents_cities)
# Out:
# 11546

# %%
sns.distplot(low_accidents_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(cities_byaccident, log_scale=True)

# %%
cities_byaccident[cities_byaccident == 1].count()
# Out:
# 1267

# %% [markdown]
# ##Start Time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 4232536    2019-08-23 18:03:25
# 4232537    2019-08-23 19:11:30
# 4232538    2019-08-23 19:00:21
# 4232539    2019-08-23 19:00:21
# 4232540    2019-08-23 18:52:06
# Name: Start_Time, Length: 4232541, dtype: object

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 05:46:00')

# %%
df.Start_Time.dt.hour
# Out:
# 0           5
# 1           6
# 2           6
# 3           7
# 4           7
#            ..
# 4232536    18
# 4232537    19
# 4232538    19
# 4232539    19
# 4232540    18
# Name: Start_Time, Length: 4232541, dtype: int64

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ####is the distribution of accidents by hour the same on weekneds as on weekdays

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
weekend_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 5]
sns.distplot(weekend_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_2019 = df[df.Start_Time.dt.year == 2020]
sns.distplot(df_2019.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.Source
# Out:
# 0          MapQuest
# 1          MapQuest
# 2          MapQuest
# 3          MapQuest
# 4          MapQuest
#              ...
# 4232536        Bing
# 4232537        Bing
# 4232538        Bing
# 4232539        Bing
# 4232540        Bing
# Name: Source, Length: 4232541, dtype: object

# %%
df_2019_bing = df_2019[df_2019.Source == 'Bing']
sns.distplot(df_2019_bing.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.Source.value_counts().plot(kind='pie')

# %% [markdown]
# ## Start Latitude & Longitude

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 4232536    34.002480
# 4232537    32.766960
# 4232538    33.775450
# 4232539    33.992460
# 4232540    34.133930
# Name: Start_Lat, Length: 4232541, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 4232536   -117.379360
# 4232537   -117.148060
# 4232538   -117.847790
# 4232539   -118.403020
# 4232540   -117.230920
# Name: Start_Lng, Length: 4232541, dtype: float64

# %%
sample_df = df.sample(int(0.1 *len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001)

# %%
import folium
from folium.plugins import HeatMap

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (39.865147, -84.058723)

# %%
sample_df = df.sample(int(0.001 *len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Summary and Insights:
#
# 1.   Accidents in different weather condition is different. December has more accidents.
# 2.   5 states with higher number of accidents
# 3.   new york city isn't in the data
# 4.   top 10 cities has huge gap among them.
# 5.   1267 cities with One accident
# 6.   Mostly accidents happen between 6 am to 10 am and 3 to 6 pm
# 7.   2020 data is very different from 2019
# 8.   December is always in the top months
# 9.   2016 doesn't have much data for all months
# 10.  Weekdends accidents happens mostly between 10 am to 3pm.
# 11.  Bing data and MapQuest data are not all same. Bing seems to be missing data.
# 12.  Generating a heatmap shows mid of the US has lesser accidents than around areas.
